# %% [markdown]
# ## Using fastText for word representations

# %%
import fasttext
model = fasttext.train_unsupervised('data/data/fil9')

# %%
model.words
# Out:
# ['the',
#  'of',
#  'one',
#  'zero',
#  'and',
#  'in',
#  'two',
#  'a',
#  'nine',
#  'to',
#  'is',
#  'eight',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'for',
#  'are',
#  'as',
#  'was',
#  's',
#  'with',
#  'by',
#  'from',
#  'that',
#  'on',
#  'or',
#  'it',
#  'at',
#  'his',
#  'an',
#  'he',
#  'have',
#  'which',
#  'be',
#  'this',
#  'there',
#  'age',
#  'also',
#  'has',
#  'population',
#  'not',
#  'were',
#  'who',
#  'other',
#  'had',
#  'but',
#  'years',
#  'all',
#  'km',
#  'their',
#  'out',
#  'new',
#  'city',
#  'under',
#  'first',
#  'more',
#  'its',
#  'american',
#  'county',
#  'they',
#  'mi',
#  'living',
#  'income',
#  'some',
#  'median',
#  'been',
#  'after',
#  'total',
#  'most',
#  'can',
#  'united',
#  'no',
#  'when',
#  'many',
#  'states',
#  'people',
#  'over',
#  'time',
#  'census',
#  'into',
#  'used',
#  'such',
#  'may',
#  'i',
#  'up',
#  'town',
#  'average',
#  'see',
#  'older',
#  'area',
#  'families',
#  'only',
#  'family',
#  'those',
#  'males',
#  'females',
#  'households',
#  'line',
#  'made',
#  'world',
#  'them',
#  'these',
#  'her',
#  'than',
#  'would',
#  'any',
#  'every',
#  'during',
#  'war',
#  'external',
#  'known',
#  'about',
#  'links',
#  'north',
#  'below',
#  'size',
#  'water',
#  'between',
#  'however',
#  'located',
#  'state',
#  'th',
#  'd',
#  'name',
#  'she',
#  'if',
#  'where',
#  'density',
#  'history',
#  'called',
#  'm',
#  'races',
#  'household',
#  'then',
#  'poverty',
#  'part',
#  'him',
#  'use',
#  'so',
#  'will',
#  'being',
#  'later',
#  'west',
#  'well',
#  'while',
#  'b',
#  'white',
#  'u',
#  'often',
#  'non',
#  'university',
#  'both',
#  'de',
#  'became',
#  'system',
#  'land',
#  'south',
#  'number',
#  'c',
#  'year',
#  'through',
#  'government',
#  'e',
#  't',
#  'children',
#  'john',
#  'township',
#  'present',
#  'according',
#  'national',
#  'like',
#  'since',
#  'early',
#  'century',
#  'british',
#  'high',
#  'because',
#  'english',
#  'school',
#  'life',
#  'several',
#  'music',
#  'general',
#  'n',
#  'same',
#  'including',
#  'before',
#  'together',
#  'series',
#  'now',
#  'per',
#  'x',
#  'king',
#  'each',
#  'work',
#  'very',
#  'film',
#  'you',
#  'married',
#  'even',
#  'second',
#  'although',
#  'day',
#  'female',
#  'village',
#  'african',
#  'against',
#  'born',
#  'much',
#  'native',
#  'york',
#  'list',
#  'french',
#  'until',
#  'race',
#  'long',
#  'could',
#  'group',
#  'public',
#  'large',
#  'what',
#  'units',
#  'great',
#  'form',
#  'based',
#  'another',
#  'party',
#  'pacific',
#  'example',
#  'g',
#  'game',
#  'st',
#  'still',
#  'individuals',
#  'power',
#  'end',
#  'major',
#  'alone',
#  'spread',
#  'do',
#  'f',
#  'ii',
#  'geography',
#  'river',
#  'husband',
#  'r',
#  'someone',
#  'us',
#  'best',
#  'asian',
#  'around',
#  'place',
#  'own',
#  'small',
#  'east',
#  'law',
#  'found',
#  'set',
#  'housing',
#  'german',
#  'bureau',
#  'president',
#  'death',
#  'language',
#  'international',
#  'different',
#  'black',
#  'left',
#  'order',
#  'racial',
#  'following',
#  'old',
#  'book',
#  'demographics',
#  'main',
#  'term',
#  'we',
#  'versus',
#  'home',
#  'house',
#  'way',
#  'p',
#  'man',
#  'did',
#  'capita',
#  'couples',
#  'usually',
#  'common',
#  'hispanic',
#  'makeup',
#  'named',
#  'country',
#  'residing',
#  'show',
#  'political',
#  'include',
#  'image',
#  'latino',
#  'modern',
#  'though',
#  'householder',
#  'within',
#  'islander',
#  'cdp',
#  'church',
#  'point',
#  'l',
#  'back',
#  'due',
#  'popular',
#  'members',
#  'last',
#  'air',
#  'official',
#  'january',
#  'right',
#  'march',
#  'military',
#  'times',
#  'among',
#  'using',
#  'original',
#  'company',
#  'cities',
#  'make',
#  'began',
#  'island',
#  'v',
#  'considered',
#  'given',
#  'london',
#  'band',
#  'battle',
#  'o',
#  'just',
#  'article',
#  'off',
#  'without',
#  'version',
#  'album',
#  'down',
#  'information',
#  'h',
#  'bc',
#  'released',
#  'site',
#  'england',
#  'college',
#  'location',
#  'j',
#  'october',
#  'france',
#  'become',
#  'september',
#  'june',
#  'army',
#  'important',
#  'december',
#  'sometimes',
#  'july',
#  'should',
#  'few',
#  'local',
#  'w',
#  'former',
#  'human',
#  'k',
#  'william',
#  'service',
#  'along',
#  'son',
#  'near',
#  'free',
#  'april',
#  'center',
#  'november',
#  'various',
#  'august',
#  'western',
#  'died',
#  'single',
#  'led',
#  'february',
#  'roman',
#  'period',
#  'james',
#  'central',
#  'god',
#  'control',
#  'others',
#  'george',
#  'similar',
#  'case',
#  'america',
#  'does',
#  'took',
#  'theory',
#  'late',
#  'games',
#  'said',
#  'less',
#  'television',
#  'force',
#  'men',
#  'space',
#  'park',
#  'thus',
#  'published',
#  'union',
#  'district',
#  'created',
#  'short',
#  'isbn',
#  'team',
#  'built',
#  'word',
#  'science',
#  'little',
#  'written',
#  'works',
#  'development',
#  'never',
#  'support',
#  'player',
#  'character',
#  'computer',
#  'must',
#  'court',
#  'famous',
#  'how',
#  'systems',
#  'take',
#  'held',
#  'community',
#  'father',
#  'side',
#  'again',
#  'third',
#  'european',
#  'generally',
#  'groups',
#  'births',
#  'canada',
#  'song',
#  'red',
#  'good',
#  'kingdom',
#  'himself',
#  'rather',
#  'story',
#  'rock',
#  'art',
#  'la',
#  'star',
#  'either',
#  'came',
#  'having',
#  'social',
#  'lake',
#  'minister',
#  'field',
#  'once',
#  'member',
#  'body',
#  'today',
#  'my',
#  'seen',
#  'books',
#  'references',
#  'northern',
#  'act',
#  'play',
#  'europe',
#  'germany',
#  'california',
#  'covered',
#  'council',
#  'played',
#  'page',
#  'earth',
#  'current',
#  'charles',
#  'uk',
#  'forces',
#  'role',
#  'society',
#  'website',
#  'open',
#  'japanese',
#  'further',
#  'light',
#  'sea',
#  'title',
#  'areas',
#  'live',
#  'region',
#  'fact',
#  'countries',
#  'class',
#  'radio',
#  'upon',
#  'especially',
#  'next',
#  'million',
#  'result',
#  'china',
#  'none',
#  'standard',
#  'type',
#  'level',
#  'top',
#  'won',
#  'royal',
#  'full',
#  'source',
#  'deaths',
#  'means',
#  'special',
#  'days',
#  'young',
#  'towns',
#  'largest',
#  'production',
#  'robert',
#  'head',
#  'texas',
#  'style',
#  'republic',
#  'league',
#  'chinese',
#  'developed',
#  'possible',
#  'process',
#  'above',
#  'almost',
#  'produced',
#  'events',
#  'established',
#  'making',
#  'person',
#  'office',
#  'data',
#  'itself',
#  'real',
#  'middle',
#  'love',
#  'included',
#  'greek',
#  'david',
#  'com',
#  'women',
#  'empire',
#  'season',
#  're',
#  'christian',
#  'available',
#  'press',
#  'taken',
#  'movement',
#  'originally',
#  'culture',
#  'movie',
#  'me',
#  'henry',
#  'washington',
#  'san',
#  'research',
#  'far',
#  'southern',
#  'design',
#  'paul',
#  'al',
#  'final',
#  'lost',
#  'record',
#  'half',
#  'languages',
#  'program',
#  'australia',
#  'position',
#  'hand',
#  'airport',
#  'actor',
#  'instead',
#  'civil',
#  'low',
#  'education',
#  'japan',
#  'related',
#  'here',
#  'capital',
#  'formed',
#  'natural',
#  'films',
#  'places',
#  'species',
#  'eastern',
#  'run',
#  'received',
#  'building',
#  'characters',
#  'go',
#  'station',
#  'parts',
#  'view',
#  'project',
#  'economic',
#  'went',
#  'change',
#  'rights',
#  'code',
#  'user',
#  'students',
#  'spanish',
#  'map',
#  'certain',
#  'street',
#  'founded',
#  'thomas',
#  'ancient',
#  'lord',
#  'terms',
#  'range',
#  'eventually',
#  'business',
#  'least',
#  'road',
#  'news',
#  'pennsylvania',
#  'continued',
#  'canadian',
#  'post',
#  'http',
#  'whose',
#  'aircraft',
#  'soviet',
#  'prime',
#  'words',
#  'records',
#  'always',
#  'energy',
#  'model',
#  'emperor',
#  'get',
#  'too',
#  'fire',
#  'career',
#  'network',
#  'your',
#  'addition',
#  'y',
#  'richard',
#  'religious',
#  'green',
#  'traditional',
#  'video',
#  'wrote',
#  'tv',
#  'saint',
#  'sound',
#  'uploaded',
#  'come',
#  'numbers',
#  'particular',
#  'software',
#  'attack',
#  'release',
#  'historical',
#  'served',
#  'trade',
#  'note',
#  'uses',
#  'india',
#  'mother',
#  'market',
#  'throughout',
#  'action',
#  'names',
#  'moved',
#  'queen',
#  'lower',
#  'might',
#  'night',
#  'away',
#  'meaning',
#  'forms',
#  'soon',
#  'schools',
#  'hall',
#  'thought',
#  'study',
#  'www',
#  'self',
#  'football',
#  'author',
#  'foreign',
#  'text',
#  'nature',
#  'return',
#  'recent',
#  'wife',
#  'independent',
#  'anti',
#  'leader',
#  'prince',
#  'technology',
#  'particularly',
#  'despite',
#  'started',
#  'players',
#  'able',
#  'russian',
#  'described',
#  'islands',
#  'jewish',
#  'services',
#  'lead',
#  'ireland',
#  'iii',
#  'our',
#  'election',
#  'future',
#  'strong',
#  'effect',
#  'base',
#  'commonly',
#  'includes',
#  'blue',
#  'elected',
#  'killed',
#  'italian',
#  'federal',
#  'themselves',
#  'designated',
#  'co',
#  'big',
#  'novel',
#  'peter',
#  'borough',
#  'michael',
#  'true',
#  'food',
#  'actually',
#  'wikipedia',
#  'ever',
#  'appeared',
#  'outside',
#  'function',
#  'award',
#  'club',
#  'catholic',
#  'currently',
#  'followed',
#  'referred',
#  'close',
#  'miles',
#  'minnesota',
#  'museum',
#  'rule',
#  'division',
#  'association',
#  'higher',
#  'across',
#  'put',
#  'paris',
#  'industry',
#  'chief',
#  'cases',
#  'value',
#  'complete',
#  'link',
#  'beginning',
#  'features',
#  'success',
#  'writer',
#  'latin',
#  'indian',
#  'returned',
#  'province',
#  'working',
#  'irish',
#  'find',
#  'louis',
#  'material',
#  'help',
#  'introduced',
#  'musical',
#  'usa',
#  'influence',
#  'therefore',
#  'subject',
#  'front',
#  'significant',
#  'africa',
#  'designed',
#  'leading',
#  'ship',
#  'coast',
#  'speed',
#  'seat',
#  'don',
#  'valley',
#  'whether',
#  'personal',
#  'cross',
#  'media',
#  'interest',
#  'brought',
#  'structure',
#  'cause',
#  'britain',
#  'points',
#  'talk',
#  'typically',
#  'practice',
#  'governor',
#  'problems',
#  'episode',
#  'associated',
#  'problem',
#  'rate',
#  'fiction',
#  'singer',
#  'better',
#  'daughter',
#  'individual',
#  'board',
#  'gave',
#  'songs',
#  'lines',
#  'mass',
#  'nations',
#  'private',
#  'virginia',
#  'michigan',
#  'sir',
#  'money',
#  'date',
#  'brother',
#  'successful',
#  'legal',
#  'shows',
#  'police',
#  'policy',
#  'writing',
#  'grand',
#  'yet',
#  'department',
#  'parliament',
#  'literature',
#  'remained',
#  'ground',
#  'performance',
#  'simply',
#  'centre',
#  'actress',
#  'navy',
#  'months',
#  'probably',
#  'larger',
#  'widely',
#  'italy',
#  'duke',
#  'australian',
#  'car',
#  'library',
#  'reference',
#  'section',
#  'ohio',
#  'earlier',
#  'health',
#  'give',
#  'types',
#  'hill',
#  'need',
#  'director',
#  'commercial',
#  'elements',
#  'peace',
#  'key',
#  'evidence',
#  'required',
#  'sun',
#  'organization',
#  'counties',
#  'dr',
#  'bridge',
#  'allowed',
#  'limited',
#  'bay',
#  'sent',
#  'playing',
#  'past',
#  'bill',
#  'security',
#  'remains',
#  'economy',
#  'changes',
#  'wide',
#  'provide',
#  'saw',
#  'move',
#  'finally',
#  'gold',
#  'longer',
#  'physical',
#  'child',
#  'surface',
#  'square',
#  'spain',
#  'construction',
#  'summer',
#  'stage',
#  'mostly',
#  'hit',
#  'web',
#  'complex',
#  'greater',
#  'majority',
#  'notable',
#  'already',
#  'whom',
#  'enough',
#  'domain',
#  'recorded',
#  'mid',
#  'z',
#  'done',
#  'internet',
#  'companies',
#  'studies',
#  'refer',
#  'makes',
#  'believed',
#  'mark',
#  'woman',
#  'method',
#  'course',
#  'examples',
#  'male',
#  'deleted',
#  'contains',
#  'caused',
#  'primary',
#  'changed',
#  'things',
#  'magazine',
#  'operation',
#  'specific',
#  'replaced',
#  'mary',
#  'nation',
#  'turn',
#  'edition',
#  'russia',
#  'territory',
#  'edward',
#  'added',
#  'whole',
#  'involved',
#  'smith',
#  'idea',
#  'ten',
#  'cover',
#  'etc',
#  'dutch',
#  'perhaps',
#  'le',
#  'jersey',
#  'say',
#  'appears',
#  'dead',
#  'sense',
#  'separate',
#  'blood',
#  'carolina',
#  'length',
#  'philosophy',
#  'basic',
#  'entire',
#  'attempt',
#  'cannot',
#  'joseph',
#  'online',
#  'mountain',
#  'bank',
#  'oil',
#  'provided',
#  'rest',
#  'pope',
#  'israel',
#  'effects',
#  'sources',
#  'towards',
#  'sold',
#  'stories',
#  'independence',
#  'route',
#  ...]

# %% [markdown]
# This is a list of words in the vocabulary sorted by decreasing frequency.

# %%
model.get_word_vector("the")
# Out:
# array([ 0.44313288, -0.06725024,  0.13870639, -0.09302375, -0.27249616,
#        -0.1452028 , -0.3291832 ,  0.08051889, -0.2243666 , -0.2281157 ,
#         0.13824797,  0.39411303, -0.00847176, -0.30919692,  0.18922739,
#        -0.10838241,  0.06304305,  0.2618296 , -0.22830428, -0.06726748,
#         0.17615782,  0.21709362, -0.04251831, -0.20397426, -0.09704718,
#        -0.15144597,  0.05906538, -0.03667366, -0.12229547,  0.18454264,
#        -0.03223861, -0.2859161 , -0.0116627 ,  0.1809985 , -0.05820664,
#        -0.00742344, -0.263299  ,  0.03419667,  0.00328209,  0.18118934,
#         0.34182513,  0.24826926,  0.1495962 ,  0.01940354,  0.03490288,
#        -0.29688522, -0.14044511, -0.2119899 , -0.296442  , -0.05040457,
#         0.34889236,  0.00795957,  0.10304486, -0.07437348, -0.3031885 ,
#        -0.01675152,  0.01628832, -0.26944453, -0.08275838,  0.14943007,
#         0.1418032 ,  0.29090133, -0.09121905,  0.05317429,  0.02159631,
#         0.18770872, -0.01779362,  0.06965798,  0.00975831, -0.15085654,
#        -0.03873964,  0.06430624,  0.28844425, -0.19338258,  0.06270944,
#         0.18209383, -0.11770342,  0.15368132,  0.14458703,  0.03812613,
#         0.0932438 ,  0.24246527,  0.19351421, -0.03140406,  0.06096565,
#        -0.06639706,  0.2668347 , -0.25481665,  0.10599669, -0.08313882,
#        -0.2848621 ,  0.136841  ,  0.46753675, -0.11607011,  0.02658413,
#        -0.4188936 ,  0.04361405, -0.2743866 ,  0.05342663, -0.23167475],
#       dtype=float32)

# %% [markdown]
# This is the word vector of the word "the". All the words in the vocabulary are represented in this format.

# %% [markdown]
# As the training took a while, we can save it and load it later.

# %%
model.save_model("result/fil9.bin")
#model = fasttext.load_model("result/fil9.bin")

# %% [markdown]
# ### Printing Word Vectors

# %% [markdown]
# We can print the word vectors of words asparagus, pidgey and yellow with the following command:

# %%
[model.get_word_vector(x) for x in ["asparagus", "pidgey", "yellow"]]
# Out:
# [array([ 0.42690518,  0.25333592,  0.35559738, -0.50758594,  0.10728838,
#          0.7777949 ,  0.06088049,  0.32230195, -0.36272103, -0.01237643,
#          0.32733086,  0.00986055, -0.63272154,  0.04458496, -0.13258888,
#          0.03049676,  0.21458305,  0.13874006,  0.04462852,  0.03653872,
#          0.33277968,  0.8327558 ,  0.29634246, -0.5567676 ,  0.2721421 ,
#         -0.42235774, -0.14641348, -0.08704136, -0.02238087, -0.33137754,
#         -0.25334537, -0.2736928 ,  0.3336205 ,  0.16857824,  0.4292296 ,
#          0.30369   , -0.41468224,  0.3929557 ,  1.1367693 , -0.28598624,
#          0.04711537,  0.20521347,  0.22843842, -0.19074629, -0.08494286,
#         -0.6705761 ,  0.20914786,  0.5104783 , -0.32072568,  0.33267644,
#          0.6045782 , -0.3321772 , -0.23552912,  0.43417615, -0.04569479,
#          0.07495809,  0.23189762, -0.0666296 , -0.46784756,  0.3590963 ,
#         -0.43390772, -0.07309743,  0.25188574,  0.14830428, -0.14054094,
#          1.1045274 ,  0.09062426, -0.26540515,  0.08476363,  0.42025983,
#         -0.23452485,  0.29117936,  0.06089348, -0.0513498 , -0.1695493 ,
#          0.768059  , -0.340816  ,  0.12693025, -0.03612741, -0.04723493,
#         -0.26994577, -0.11943955,  0.09255791,  0.6082469 ,  0.27367014,
#         -0.11819067, -0.262799  ,  0.21954428, -0.1819045 ,  0.18101385,
#         -0.23261721,  0.09752379,  0.5098576 , -0.54827607, -0.27998397,
#         -0.68467325, -0.02979985, -0.34918487, -0.07436121,  0.21103671],
#        dtype=float32),
#  array([-0.00989046,  0.19433579,  0.3946756 ,  0.12655887,  0.34079278,
#          0.30465898, -0.09225962,  0.15657435,  0.0613068 , -0.00964017,
#          0.31975058,  0.3569917 , -0.36448115, -0.3027432 ,  0.53866005,
#         -0.09606192, -0.49191386, -0.32999074, -0.08753944, -0.03021129,
#          0.40983507,  0.09258886,  0.61822975, -0.62709653, -0.36941016,
#         -0.5474872 ,  0.13414907, -0.31188318, -0.28571248,  0.2821807 ,
#          0.06929728, -0.16143174,  0.5092512 ,  0.1303286 ,  0.561294  ,
#          0.24726336, -0.60168296,  0.02162734,  0.62828493,  0.33990997,
#          0.14264415,  0.48912907, -0.10389085,  0.41960758, -0.0760824 ,
#         -0.6385657 ,  0.04808411,  0.1689749 ,  0.07675682,  0.01498323,
#          0.28857747, -0.5189489 , -0.09426216,  0.07967456,  0.02312726,
#          0.19910644, -0.35037273, -0.51742315,  0.20833081, -0.15256597,
#          0.49720544,  0.3146217 ,  0.29498532, -0.17811301, -0.25478023,
#          0.3984542 , -0.04599931,  0.16033268, -0.21103863, -0.31965005,
#         -0.30030814, -0.2062708 ,  0.12744303,  0.33828273,  0.08325408,
#          1.230155  , -0.08620641, -0.30808437, -0.61314327,  0.15044174,
#         -0.89623934, -0.3182766 , -0.08407418,  0.17674391,  0.11589812,
#          0.6985647 , -0.26930615,  0.1516879 ,  0.03209892,  0.07106038,
#         -0.3085142 ,  0.5425531 ,  0.08367975, -0.19200546, -0.48148853,
#         -0.22161253, -0.05450505, -0.5655503 ,  0.10428765, -0.6691697 ],
#        dtype=float32),
#  array([ 0.6394315 , -0.15057665,  0.07747045,  0.11096004,  0.12849279,
#         -0.14547616, -0.16571233, -0.14191034, -0.01575775, -0.01532889,
#          0.5007823 ,  0.24307394, -0.3070267 , -0.32541883, -0.08913221,
#          0.14350016, -0.0477679 ,  0.10131259, -0.6519562 ,  0.46031138,
#         -0.5072049 ,  0.48727095,  0.6531469 , -0.41493106,  0.0115878 ,
#         -0.33521947, -0.09112764, -0.05659791, -0.460263  ,  0.5993307 ,
#          0.0164833 , -0.11865789,  0.10438223,  0.45043954,  0.47321978,
#          0.6667934 , -0.678322  ,  0.3663344 ,  0.12832305,  0.5376886 ,
#         -0.24218298,  0.08170305,  0.12858526, -0.44964263, -0.14042099,
#         -0.1859367 ,  0.20875779,  0.35598764, -0.42156023, -0.30455408,
#         -0.28693694, -0.00652139,  0.03537719,  0.15326265, -0.37744117,
#         -0.8366219 , -0.04796207, -0.2827263 , -0.8005376 ,  0.39987352,
#         -0.15944609,  0.29691482,  0.37591186, -0.01112451, -0.02965009,
#          0.37116167, -0.08556332,  0.5404119 ,  0.46016532, -0.04999881,
#         -0.42921454,  0.14692897,  0.58413935, -0.4451836 ,  0.09208868,
#          0.1994214 ,  0.07874036, -0.14387271, -0.32601288, -0.254634  ,
#         -0.47448003, -0.285249  , -0.11338236,  0.24237868,  0.30153012,
#          0.33896014, -0.41462   , -0.10615452,  0.11357906,  0.0861482 ,
#          0.30237713,  0.35958472,  0.6179662 , -0.19553696, -0.01616268,
#         -0.10472918, -0.2958445 , -0.5636246 ,  0.41681296,  0.15092571],
#        dtype=float32)]

# %% [markdown]
# A nice feature is that you can also query for words that did not appear in your data! Indeed words are represented by the sum of its substrings. As long as the unknown word is made of known substrings, there is a representation of it!
#
# As an example let's try with a misspelled word:

# %%
model.get_word_vector("enviroment")
# Out:
# array([ 0.55878055, -0.09884794,  0.01644679, -0.01564694,  0.4957327 ,
#         0.07122821, -0.35701048,  0.06908209, -0.48953786, -0.19269708,
#        -0.2320794 ,  0.67147803, -0.08004352, -0.02940788,  0.00430572,
#        -0.17793663,  0.19303249,  0.05925313, -0.09072658, -0.01990304,
#         0.3315585 ,  0.2828672 ,  0.26893455, -0.1239673 , -0.0416136 ,
#         0.08420929,  0.11877447,  0.14720206, -0.01383709,  0.25763714,
#         0.06215807, -0.01858872,  0.11674039, -0.0890514 ,  0.2559311 ,
#        -0.24585488, -0.7545257 ,  0.54074055, -0.20922379, -0.09910334,
#         0.13268295,  0.2351052 ,  0.0445831 ,  0.44643945,  0.07826214,
#        -0.5003347 , -0.09126402, -0.07871318, -0.12277444,  0.09350567,
#        -0.00954623,  0.02424753,  0.06288505,  0.0845123 , -0.01981117,
#        -0.1644663 , -0.14672217, -0.1898063 , -0.04739422, -0.155867  ,
#         0.22146717, -0.14510304,  0.10355323, -0.2500524 , -0.0230857 ,
#         0.20133856, -0.38991705,  0.19892141,  0.30788   ,  0.67747396,
#        -0.18970017,  0.14466418,  0.14245076,  0.40480918, -0.14849484,
#         0.22648427, -0.01361351, -0.08401994, -0.25839692, -0.11584739,
#         0.30783564,  0.18695593,  0.03892629,  0.11292225,  0.29494455,
#        -0.24458478,  0.08253679, -0.17473616, -0.4729019 ,  0.3166026 ,
#         0.10613555,  0.21523423,  0.0165502 , -0.11784318,  0.25671676,
#        -0.2958519 ,  0.15158768, -0.2372123 ,  0.08182767,  0.13628827],
#       dtype=float32)

# %% [markdown]
# ### Nearest Neighbours Queries:

# %% [markdown]
# A simple way to check the quality of a word vector is to look at its nearest neighbors. This give an intuition of the type of semantic information the vectors are able to capture.
#
# This can be achieved with the nearest neighbor (nn) functionality. For example, we can query the 10 nearest neighbors of a word by running the following command:

# %%
model.get_nearest_neighbors('asparagus')
# Out:
# [(0.7878556847572327, 'walnuts'),
#  (0.7779132127761841, 'beetroot'),
#  (0.7738654017448425, 'tomato'),
#  (0.7719115018844604, 'cabbages'),
#  (0.7715265154838562, 'asparagales'),
#  (0.7711346745491028, 'chickpea'),
#  (0.7707504630088806, 'arrowroot'),
#  (0.7656763792037964, 'chickpeas'),
#  (0.7650848031044006, 'cabbage'),
#  (0.7636562585830688, 'vegetables')]

# %% [markdown]
# Nice! It seems that vegetable vectors are similar. What about pokemons?

# %%
model.get_nearest_neighbors('pidgey')
# Out:
# [(0.9023844599723816, 'pidgeot'),
#  (0.8883858323097229, 'pidgeotto'),
#  (0.8718113899230957, 'pidge'),
#  (0.7840093970298767, 'charizard'),
#  (0.7751268148422241, 'pikachu'),
#  (0.7671030759811401, 'beedrill'),
#  (0.7573469877243042, 'charmeleon'),
#  (0.7519928216934204, 'pidgeon'),
#  (0.751587450504303, 'pok'),
#  (0.735741376876831, 'squirtle')]

# %% [markdown]
# Different evolution of the same Pokemon have close-by vectors! But what about our misspelled word, is its vector close to anything reasonable? Let's find out:

# %%
model.get_nearest_neighbors('enviroment')
# Out:
# [(0.8944371342658997, 'enviromental'),
#  (0.8718078136444092, 'environ'),
#  (0.835297167301178, 'enviro'),
#  (0.7783136963844299, 'environs'),
#  (0.760940432548523, 'enviromission'),
#  (0.757567822933197, 'environnement'),
#  (0.6687712669372559, 'environment'),
#  (0.6484033465385437, 'realclimate'),
#  (0.6476025581359863, 'ecotourism'),
#  (0.6470270752906799, 'acclimatation')]

# %% [markdown]
# Thanks to the information contained within the word, the vector of our misspelled word matches to reasonable words! It is not perfect but the main information has been captured.

# %% [markdown]
# In order to find nearest neighbors, we need to compute a similarity score between words. Our words are represented by continuous word vectors and we can thus apply simple similarities to them. In particular we use the cosine of the angles between two vectors. This similarity is computed for all words in the vocabulary, and the 10 most similar words are shown. Of course, if the word appears in the vocabulary, it will appear on top, with a similarity of 1.

# %% [markdown]
# ### Word Analogies

# %% [markdown]
# In a similar spirit, one can play around with word analogies. For example, we can see if our model can guess what is to France, and what Berlin is to Germany.
#
# This can be done with the analogies functionality. It takes a word triplet (like Germany Berlin France) and outputs the analogy:

# %%
model.get_analogies("berlin", "germany", "france")
# Out:
# [(0.8991923332214355, 'paris'),
#  (0.7859027981758118, 'dubourg'),
#  (0.7838226556777954, 'valenciennes'),
#  (0.7820677757263184, 'faubourg'),
#  (0.7773563265800476, 'maubourg'),
#  (0.7770666480064392, 'louveciennes'),
#  (0.7768223285675049, 'dessaulles'),
#  (0.7706047892570496, 'beaubourg'),
#  (0.7634151577949524, 'pompignan'),
#  (0.7581263780593872, 'montpellier')]

# %% [markdown]
# The answer provided by our model is Paris, which is correct. Let's have a look at a less obvious example:

# %%
model.get_analogies("psx", "sony", "nintendo")
# Out:
# [(0.7998178005218506, 'dreamcast'),
#  (0.7940496206283569, 'gamecube'),
#  (0.7940258383750916, 'sega'),
#  (0.7918456792831421, 'gba'),
#  (0.7733192443847656, 'playstation'),
#  (0.7727131247520447, 'nintendogs'),
#  (0.767773449420929, 'arcade'),
#  (0.7618235349655151, 'gameboy'),
#  (0.7574592232704163, 'capcom'),
#  (0.7501713037490845, 'famicom')]

# %% [markdown]
# Our model considers that the nintendo analogy of a psx is the dreamcast, which seems reasonable. Of course the quality of the analogies depend on the dataset used to train the model.

# %% [markdown]
# Using subword-level information is particularly interesting to build vectors for unknown words. For example, the word gearshift does not exist on Wikipedia but we can still query its closest existing words:

# %%
model.get_nearest_neighbors('gearshift')
# Out:
# [(0.7984798550605774, 'gearing'),
#  (0.7829551696777344, 'gears'),
#  (0.7524955868721008, 'daisywheel'),
#  (0.7510121464729309, 'freewheel'),
#  (0.7467069029808044, 'driveshaft'),
#  (0.7466177344322205, 'cogwheels'),
#  (0.7461075186729431, 'driveshafts'),
#  (0.7454342246055603, 'flywheel'),
#  (0.7410158514976501, 'flywheels'),
#  (0.7373144626617432, 'wheelset')]

# %% [markdown]
# Most of the retrieved words share substantial substrings but a few are actually quite different, like cogwheels.

# %% [markdown]
# Now that we have seen the interest of subword information for unknown words, let's check how it compares to a model that does not use subword information. To train a model without subwords, just run the following command:

# %%
model_without_subwords = fasttext.train_unsupervised('data/data/fil9', maxn=0)
model_without_subwords.get_nearest_neighbors('accomodation')
# Out:
# [(0.80191969871521, 'tyresta'),
#  (0.7933712601661682, 'uutela'),
#  (0.7897980809211731, 'agrotourism'),
#  (0.7783662676811218, 'hostelling'),
#  (0.7750516533851624, 'laponian'),
#  (0.7545826435089111, 'radzima'),
#  (0.7535238265991211, 'rauland'),
#  (0.752931535243988, 'tresticklan'),
#  (0.7523895502090454, 'maranoa'),
#  (0.7478064894676208, 'bothel')]

# %% [markdown]
# The result does not make much sense, most of these words are unrelated. On the other hand, using subword information gives the following list of nearest neighbors:

# %%
model.get_nearest_neighbors('accomodation')
# Out:
# [(0.9611985087394714, 'accomodations'),
#  (0.9291858077049255, 'accommodation'),
#  (0.9038296341896057, 'accommodations'),
#  (0.8348402976989746, 'accommodative'),
#  (0.7768381237983704, 'accommodating'),
#  (0.7459931969642639, 'amenities'),
#  (0.7376998662948608, 'lodging'),
#  (0.7359251976013184, 'ammenities'),
#  (0.7227441072463989, 'accomodated'),
#  (0.7025332450866699, 'accomodate')]

# %% [markdown]
# The nearest neighbors capture different variation around the word accommodation. We also get semantically related words such as amenities or lodging.
